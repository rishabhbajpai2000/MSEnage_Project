# %%
# reading the file
import pandas as pd
data = pd.read_csv("Data.csv")

# %%
# cleaning the data
# making the values of the as float from intger.  
data["ARAI_Certified_Mileage_kmpl"].astype(float)
# Out:
# 0         NaN
# 1        8.00
# 2       12.90
# 3       20.38
# 4       20.38
#         ...
# 1271    13.80
# 1272    23.00
# 1273    23.00
# 1274    13.51
# 1275    18.18
# Name: ARAI_Certified_Mileage_kmpl, Length: 1276, dtype: float64

# %%
filter_p = data[data["Ex-Showroom_Price"].isin(range(100000, 1000000))]
# filter_price

# %%
filter_b_p = filter_p[filter_p["Make"] == "Tata"]
# filter_brand

# %%
filter_b_p_t = filter_b_p[filter_b_p["Fuel_Type"]  == "Petrol"]
# filter_type

# %%
filter_b_m_p_t = filter_b_p_t[filter_b_p_t["ARAI_Certified_Mileage_kmpl"].isin(range(10, 30))]

# %%
filter_b_m_p_t.sort_values("Ex-Showroom_Price").head()
# Out:
#      Unnamed: 0  Make   Model      Variant  Ex-Showroom_Price Displacement  \
# 973          54  Tata   Tiago  Revotron Xe             460000      1199 cc
# 974          55  Tata   Tiago  Revotron Xt             520000      1199 cc
# 989         430  Tata  Altroz    Xe Petrol             529000      1199 cc
# 975          56  Tata   Tiago  Revotron Xz             570000      1199 cc
# 999         451  Tata   Tigor  Revotron Xe             575000      1199 cc
#
#      Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 973        3.0                  4.0  FWD (Front Wheel Drive)
# 974        3.0                  4.0  FWD (Front Wheel Drive)
# 989        3.0                  4.0  FWD (Front Wheel Drive)
# 975        3.0                  4.0  FWD (Front Wheel Drive)
# 999        3.0                  4.0  FWD (Front Wheel Drive)
#
#     Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 973                In-line  ...                      NaN                 NaN
# 974                In-line  ...                      NaN                 NaN
# 989                In-line  ...                      NaN                 NaN
# 975                In-line  ...                      NaN                 NaN
# 999                In-line  ...                      NaN                 NaN
#
#                    Engine_Type ASR_/_Traction_Control Cruise_Control  \
# 973                        NaN                    NaN            NaN
# 974                        NaN                    NaN            NaN
# 989     1.2 L Revotron (BS VI)                    NaN            NaN
# 975                        NaN                    NaN            NaN
# 999  Revotron 1.2 L BS6 Engine                    NaN            NaN
#
#     USB_Ports Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 973       NaN              NaN            NaN     NaN             NaN
# 974       NaN              NaN            NaN     NaN             NaN
# 989       NaN              NaN            NaN     NaN             NaN
# 975       NaN              NaN            NaN     NaN             NaN
# 999       NaN              NaN            NaN     NaN             NaN
#
# [5 rows x 141 columns]

# %%
# final function

# reading the file
import pandas as pd
main_data = pd.read_csv("Data.csv")

# cleaning the data
# making the values of the as float from intger.  
main_data["ARAI_Certified_Mileage_kmpl"].astype(float)


#writing the main function
def cars(cost, brand, milege, p_d_cng, seating, data=main_data):
    filter_p = data[data["Ex-Showroom_Price"].isin(range(cost[0],cost[1]))]
    filter_b_p = filter_p[filter_p["Make"] == brand]
    filter_b_p_t = filter_b_p[filter_b_p["Fuel_Type"]  == p_d_cng]
    filter_b_m_p_t = filter_b_p_t[filter_b_p_t["ARAI_Certified_Mileage_kmpl"].isin(range(milege[0], milege[1]))]
    filter_b_m_p_s_t = filter_b_m_p_t[filter_b_m_p_t["Seating"] == seating]
    filter_b_m_p_s_t.sort_values("Ex-Showroom_Price").head()
    return filter_b_m_p_s_t
